# %%
from data_loader import cargar_precipitacion, cargar_oni, combinar_datos
from analytics import calcular_correlacion_lags, detectar_anomalias

df_precip = cargar_precipitacion()
df_oni    = cargar_oni()
df        = combinar_datos(df_precip, df_oni)

# Prueba con Pereira
pereira = df[df["muni_code"] == "66001"]
print(pereira.head())

from analytics import calcular_correlacion_lags, detectar_anomalias
lags = calcular_correlacion_lags(pereira)
print(lags)
# Out:
# 2026-05-30 20:50:21.878 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-05-30 20:50:21.894 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-05-30 20:50:21.896 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-05-30 20:50:21.896 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-05-30 20:50:21.896 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-05-30 20:50:21.896 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-05-30 20:50:21.908 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# ...
